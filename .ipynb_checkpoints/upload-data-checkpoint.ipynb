# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
ls
# Out:
# Dockerfile      ny_taxi_postgres_data/  upload-data.ipynb
# README.md       pipeline.py             yellow_head.csv
# Untitled.ipynb  textpad                 yellow_tripdata_2021-01.parquet
# convert-csv.py  upload-data-old.ipynb

# %%
df = pd.read_parquet('yellow_tripdata_2021-01.parquet')
df.to_csv('yellow_tripdata_2021-01.csv')

# %%
ls
# Out:
# Dockerfile      ny_taxi_postgres_data/  upload-data.ipynb
# README.md       pipeline.py             yellow_head.csv
# Untitled.ipynb  textpad                 yellow_tripdata_2021-01.csv
# convert-csv.py  upload-data-old.ipynb   yellow_tripdata_2021-01.parquet

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
df
# Out:
#     Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0            0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1            1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2            2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3            3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4            4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ..         ...       ...                  ...                   ...
# 95          95         2  2021-01-01 00:12:41   2021-01-01 00:26:47
# 96          96         2  2021-01-01 00:23:29   2021-01-01 00:35:03
# 97          97         2  2021-01-01 00:46:17   2021-01-01 00:54:25
# 98          98         2  2021-01-01 00:28:16   2021-01-01 00:51:44
# 99          99         2  2021-01-01 00:42:35   2021-01-01 00:54:41
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               1.0           2.10         1.0                  N
# 1               1.0           0.20         1.0                  N
# 2               1.0          14.70         1.0                  N
# 3               0.0          10.60         1.0                  N
# 4               1.0           4.94         1.0                  N
# ..              ...            ...         ...                ...
# 95              1.0           4.13         1.0                  N
# 96              2.0           4.12         1.0                  N
# 97              2.0           2.22         1.0                  N
# 98              1.0           7.11         1.0                  N
# 99              3.0           1.61         1.0                  N
#
#     PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            142            43             2          8.0    3.0      0.5
# 1            238           151             2          3.0    0.5      0.5
# 2            132           165             1         42.0    0.5      0.5
# 3            138           132             1         29.0    0.5      0.5
# 4             68            33             1         16.5    0.5      0.5
# ..           ...           ...           ...          ...    ...      ...
# 95           161           226             1         14.5    0.5      0.5
# 96           162            74             2         13.5    0.5      0.5
# 97           144           170             1          9.0    0.5      0.5
# 98           264           264             2         23.5    0.5      0.5
# 99           229           237             2          9.5    0.5      0.5
#
#     tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.00           0.0                    0.3         11.80
# 1         0.00           0.0                    0.3          4.30
# 2         8.65           0.0                    0.3         51.95
# 3         6.05           0.0                    0.3         36.35
# 4         4.06           0.0                    0.3         24.36
# ..         ...           ...                    ...           ...
# 95        3.66           0.0                    0.3         21.96
# 96        0.00           0.0                    0.3         17.30
# 97        2.56           0.0                    0.3         15.36
# 98        0.00           0.0                    0.3         24.80
# 99        0.00           0.0                    0.3         13.30
#
#     congestion_surcharge  airport_fee
# 0                    2.5          NaN
# 1                    0.0          NaN
# 2                    0.0          NaN
# 3                    0.0          NaN
# 4                    2.5          NaN
# ..                   ...          ...
# 95                   2.5          NaN
# 96                   2.5          NaN
# 97                   2.5          NaN
# 98                   0.0          NaN
# 99                   2.5          NaN
#
# [100 rows x 20 columns]

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "Unnamed: 0" INTEGER,
#   "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 from sqlalchemy import create_engine
# ----> 2 engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/engine/create.py:602, in create_engine(url, **kwargs)
#     600         if k in kwargs:
#     601             dbapi_args[k] = pop_kwarg(k)
# --> 602     dbapi = dbapi_meth(**dbapi_args)
#     604 dialect_args["dbapi"] = dbapi
#     606 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:696, in PGDialect_psycopg2.import_dbapi(cls)
#     694 @classmethod
#     695 def import_dbapi(cls):
# --> 696     import psycopg2
#     698     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "Unnamed: 0" INTEGER,
#   "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df
# Out:
#        Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0               0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1               1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2               2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3               3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4               4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ...           ...       ...                  ...                   ...
# 99995       99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52
# 99996       99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45
# 99997       99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22
# 99998       99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37
# 99999       99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                  1.0           2.10         1.0                  N
# 1                  1.0           0.20         1.0                  N
# 2                  1.0          14.70         1.0                  N
# 3                  0.0          10.60         1.0                  N
# 4                  1.0           4.94         1.0                  N
# ...                ...            ...         ...                ...
# 99995              3.0           0.70         1.0                  N
# 99996              2.0           3.30         1.0                  N
# 99997              2.0           4.70         1.0                  N
# 99998              2.0          17.95         2.0                  N
# 99999              5.0           0.37         1.0                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0               142            43             2          8.0    3.0      0.5
# 1               238           151             2          3.0    0.5      0.5
# 2               132           165             1         42.0    0.5      0.5
# 3               138           132             1         29.0    0.5      0.5
# 4                68            33             1         16.5    0.5      0.5
# ...             ...           ...           ...          ...    ...      ...
# 99995           234           224             2          5.0    2.5      0.5
# 99996           234           236             1         14.5    2.5      0.5
# 99997           236            79             1         17.0    2.5      0.5
# 99998           132           148             1         52.0    0.0      0.5
# 99999           236           236             2          5.0    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0            0.00           0.0                    0.3         11.80
# 1            0.00           0.0                    0.3          4.30
# 2            8.65           0.0                    0.3         51.95
# 3            6.05           0.0                    0.3         36.35
# 4            4.06           0.0                    0.3         24.36
# ...           ...           ...                    ...           ...
# 99995        0.00           0.0                    0.3          8.30
# 99996        3.55           0.0                    0.3         21.35
# 99997        4.05           0.0                    0.3         24.35
# 99998        5.00           0.0                    0.3         60.30
# 99999        0.00           0.0                    0.3          8.30
#
#        congestion_surcharge  airport_fee
# 0                       2.5          NaN
# 1                       0.0          NaN
# 2                       0.0          NaN
# 3                       0.0          NaN
# 4                       2.5          NaN
# ...                     ...          ...
# 99995                   2.5          NaN
# 99996                   2.5          NaN
# 99997                   2.5          NaN
# 99998                   2.5          NaN
# 99999                   2.5          NaN
#
# [100000 rows x 20 columns]

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace)
# Out:
#   Cell In[29], line 1
#     df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace)
#                                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df
# Out:
#        Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0               0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1               1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2               2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3               3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4               4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ...           ...       ...                  ...                   ...
# 99995       99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52
# 99996       99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45
# 99997       99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22
# 99998       99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37
# 99999       99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                  1.0           2.10         1.0                  N
# 1                  1.0           0.20         1.0                  N
# 2                  1.0          14.70         1.0                  N
# 3                  0.0          10.60         1.0                  N
# 4                  1.0           4.94         1.0                  N
# ...                ...            ...         ...                ...
# 99995              3.0           0.70         1.0                  N
# 99996              2.0           3.30         1.0                  N
# 99997              2.0           4.70         1.0                  N
# 99998              2.0          17.95         2.0                  N
# 99999              5.0           0.37         1.0                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0               142            43             2          8.0    3.0      0.5
# 1               238           151             2          3.0    0.5      0.5
# 2               132           165             1         42.0    0.5      0.5
# 3               138           132             1         29.0    0.5      0.5
# 4                68            33             1         16.5    0.5      0.5
# ...             ...           ...           ...          ...    ...      ...
# 99995           234           224             2          5.0    2.5      0.5
# 99996           234           236             1         14.5    2.5      0.5
# 99997           236            79             1         17.0    2.5      0.5
# 99998           132           148             1         52.0    0.0      0.5
# 99999           236           236             2          5.0    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0            0.00           0.0                    0.3         11.80
# 1            0.00           0.0                    0.3          4.30
# 2            8.65           0.0                    0.3         51.95
# 3            6.05           0.0                    0.3         36.35
# 4            4.06           0.0                    0.3         24.36
# ...           ...           ...                    ...           ...
# 99995        0.00           0.0                    0.3          8.30
# 99996        3.55           0.0                    0.3         21.35
# 99997        4.05           0.0                    0.3         24.35
# 99998        5.00           0.0                    0.3         60.30
# 99999        0.00           0.0                    0.3          8.30
#
#        congestion_surcharge  airport_fee
# 0                       2.5          NaN
# 1                       0.0          NaN
# 2                       0.0          NaN
# 3                       0.0          NaN
# 4                       2.5          NaN
# ...                     ...          ...
# 99995                   2.5          NaN
# 99996                   2.5          NaN
# 99997                   2.5          NaN
# 99998                   2.5          NaN
# 99999                   2.5          NaN
#
# [100000 rows x 20 columns]

# %%
engine.connect()

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
$time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
#   Cell In[34], line 1
#     $time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
#     ^
# SyntaxError: invalid syntax

# %%
df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    print('inserted another block..., took %.3f seconds' % (t_end - t_start) )
# Out:
# inserted another block..., took 11.102 seconds
# inserted another block..., took 10.937 seconds
# inserted another block..., took 11.702 seconds
# inserted another block..., took 11.336 seconds
# inserted another block..., took 10.709 seconds
# inserted another block..., took 11.766 seconds
# /tmp/ipykernel_91618/2501333495.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# inserted another block..., took 11.455 seconds
# inserted another block..., took 11.353 seconds
# inserted another block..., took 12.017 seconds
# inserted another block..., took 11.781 seconds
# inserted another block..., took 11.039 seconds
# /tmp/ipykernel_91618/2501333495.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another block..., took 11.072 seconds
# inserted another block..., took 7.132 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[37], line 3
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       4     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#       5     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:863, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
